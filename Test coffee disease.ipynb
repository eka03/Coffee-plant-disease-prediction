# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %% [raw]
# import requests
# from PIL import Image
# from io import BytesIO
# import urllib.parse
# from IPython.display import display
#
# def get_saved_url(file_path='saved_url.txt'):
#     try:
#         with open(file_path, 'r') as file:
#             return file.read().strip()
#     except FileNotFoundError:
#         print(f"File {file_path} not found. Please save a URL using the HTML page first.")
#         return None
#
# # Get the saved URL
# url_value = get_saved_url()
# print(f"Retrieved URL: {url_value}")
#
# if url_value:
#     # Ensure the URL has a scheme
#     parsed_url = urllib.parse.urlparse(url_value)
#     if not parsed_url.scheme:
#         url_value = 'http://' + url_value
#
#     try:
#         # Fetch the image
#         response = requests.get(url_value)
#         response.raise_for_status()
#         img = Image.open(BytesIO(response.content))
#
#         # Display the image
#         display(img)
#
#         # If you want to save the image, uncomment the next line
#         # img.save('downloaded_image.jpg')
#     except requests.exceptions.RequestException as e:
#         print(f"Error fetching image: {e}")
#     except Image.UnidentifiedImageError:
#         print("Error: Unable to identify image file")
# else:
#     print("Please enter a URL in the HTML page and save it to a file first.")

# %%
model = tf.keras.models.load_model('trained_plant_disease_model.keras')

# %%
model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_50 (Conv2D)                   │ (None, 128, 128, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_51 (Conv2D)                   │ (None, 126, 126, 32)        │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_30 (MaxPooling2D)      │ (None, 63, 63, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_52 (Conv2D)                   │ (None, 63, 63, 64)          │          18,496 │
# ...

# %% [markdown]
# # Visualising and Performing Prediction on Single image

# %% [markdown]
# ### for image in file

# %%
#Test Image Visualization
import cv2
image_path = 'test/class_1/C2P17H2_jpg.rf.536cf5b6815e3bf8a6adfeb88431241b.jpg'
# Reading an image in default mode
img = cv2.imread(image_path)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB) #Converting BGR to RGB
# Displaying the image 
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# ### For image as link

# %% [raw]
# import requests
# from PIL import Image
# import cv2
# import numpy as np
# import matplotlib.pyplot as plt
#
# response = requests.get("https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQsRkaYUAfybAdkn4ZTPLSqLrvauiPGAL8eyw&s")
# img = Image.open(requests.get(response.url, stream=True).raw)
# img = cv2.cvtColor(np.array(img), cv2.COLOR_RGB2BGR)
#
# plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
# plt.title('Test Image')
# plt.xticks([])
# plt.yticks([])
# plt.show()

# %%
image = tf.keras.preprocessing.image.load_img(image_path,target_size=(128,128))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
input_arr = np.array([input_arr])  # Convert single image to a batch.
predictions = model.predict(input_arr)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step

# %%
print(predictions)
# Out:
# [[0.11598137 0.72837913 0.15563947]]

# %%
result_index = np.argmax(predictions) #Return index of max element
print(result_index)
# Out:
# 1

# %%
class_name =['Healthy', 'Red Spider Mite', 'Rust']

# %%
# Displaying the disease prediction
model_prediction = class_name[result_index]
plt.imshow(img)
plt.title(f"Disease Name: {model_prediction}")
plt.xticks([])
plt.yticks([])
plt.show()

# %%
if  model_prediction =="Healthy" :
    print("Crop Production is not Effected")
elif model_prediction =="Red Spider Mite":
        print("Crop Production is  Effected by approxmiately 50%")
elif model_prediction =="Rust": 
    print("Crop Production is  Effected by approxmiately 30 - 80%")
# Out:
# Crop Production is  Effected by approxmiately 50%

# %% [markdown]
# from flask import Flask, request, jsonify
# import os
#
# app = Flask(__name__)
#
# # Route to process the uploaded URL and return results
# @app.route('/process', methods=['POST'])
# def process_url():
#     data = request.json
#     if not data or 'imageUrl' not in data:
#         return jsonify({"error": "Invalid input, 'imageUrl' is required."}), 400
#
#     image_url = data['imageUrl']
#
#     # Here, you would include logic to process the image URL in your Python code.
#     # For example, this could involve running a model or some analysis.
#
#     # Simulating a result for demonstration purposes
#     result = {
#         "imageUrl": image_url,
#         "analysis": "This is a simulated analysis result."
#     }
#
#     # Optionally, save the result to a file
#     with open('output.txt', 'w') as f:
#         f.write(f"Image URL: {image_url}\n")
#         f.write(f"Analysis: {result['analysis']}\n")
#
#     return jsonify(result)
#
# if __name__ == '__main__':
#     # Run the Flask app on localhost, port 5000
#     app.run(debug=True)
